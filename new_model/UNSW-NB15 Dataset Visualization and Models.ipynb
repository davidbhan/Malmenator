# %%
# Load and combine data

# UNSW-NB15
# https://www.unsw.adfa.edu.au/unsw-canberra-cyber/cybersecurity/ADFA-NB15-Datasets/

import os
import pandas as pd
import numpy as np

from sklearn.utils import resample
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.manifold import TSNE
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, f1_score, accuracy_score, precision_recall_fscore_support, confusion_matrix, plot_confusion_matrix
from sklearn.ensemble import RandomForestClassifier

from xgboost import XGBClassifier
from lightgbm import LGBMClassifier

from joblib import dump, load
from skl2onnx import convert_sklearn
from skl2onnx.common.data_types import FloatTensorType

import seaborn as sns
import matplotlib.pyplot as plt

pd.set_option('display.max_columns', 200)
pd.set_option('display.max_rows', 200)

columns=['srcip', 'sport', 'dstip', 'dsport', 'proto', 'state', 'dur', 'sbytes', 
         'dbytes', 'sttl', 'dttl', 'sloss', 'dloss', 'service', 'Sload', 'Dload', 
         'Spkts', 'Dpkts', 'swin', 'dwin', 'stcpb', 'dtcpb', 'smeansz', 'dmeansz', 
         'trans_depth', 'res_bdy_len', 'Sjit', 'Djit', 'Stime', 'Ltime', 'Sintpkt', 
         'Dintpkt', 'tcprtt', 'synack', 'ackdat', 'is_sm_ips_ports', 'ct_state_ttl', 
         'ct_flw_http_mthd', 'is_ftp_login', 'ct_ftp_cmd', 'ct_srv_src', 'ct_srv_dst', 
         'ct_dst_ltm', 'ct_src_ltm', 'ct_src_dport_ltm', 'ct_dst_sport_ltm', 
         'ct_dst_src_ltm', 'attack_cat', 'Label']

df = pd.DataFrame(columns=columns)

for dirname, _, filenames in os.walk('/Users/davidhan/Documents/HKU/Year_4/Final_Year_Project/research/unsw-nb15/raw'):
    for filename in filenames:
        path = os.path.join(dirname, filename)
        print("Loading data from", path)
        df_temp = pd.read_csv(path, header=None, names=columns)
        df = df.append(df_temp, ignore_index = True)
        
df.info(null_counts=True)
# Out:
# Loading data from /Users/davidhan/Documents/HKU/Year_4/Final_Year_Project/research/unsw-nb15/raw/UNSW-NB15_3.csv
# Loading data from /Users/davidhan/Documents/HKU/Year_4/Final_Year_Project/research/unsw-nb15/raw/UNSW-NB15_2.csv
# /Users/davidhan/dev/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (3,39,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Loading data from /Users/davidhan/Documents/HKU/Year_4/Final_Year_Project/research/unsw-nb15/raw/UNSW-NB15_1.csv
# /Users/davidhan/dev/ml_env/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3063: DtypeWarning: Columns (1,3,47) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# Loading data from /Users/davidhan/Documents/HKU/Year_4/Final_Year_Project/research/unsw-nb15/raw/UNSW-NB15_4.csv
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2540047 entries, 0 to 2540046
# Data columns (total 49 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   srcip             2540047 non-null  object
#  1   sport             2540047 non-null  object
#  2   dstip             2540047 non-null  object
#  3   dsport            2540047 non-null  object
#  4   proto             2540047 non-null  object
#  5   state             2540047 non-null  object
#  6   dur               2540047 non-null  float64
#  7   sbytes            2540047 non-null  object
#  8   dbytes            2540047 non-null  object
#  9   sttl              2540047 non-null  object
#  10  dttl              2540047 non-null  object
#  11  sloss             2540047 non-null  object
#  12  dloss             2540047 non-null  object
#  13  service           2540047 non-null  object
#  14  Sload             2540047 non-null  float64
#  15  Dload             2540047 non-null  float64
#  16  Spkts             2540047 non-null  object
#  17  Dpkts             2540047 non-null  object
#  18  swin              2540047 non-null  object
#  19  dwin              2540047 non-null  object
#  20  stcpb             2540047 non-null  object
#  21  dtcpb             2540047 non-null  object
#  22  smeansz           2540047 non-null  object
#  23  dmeansz           2540047 non-null  object
#  24  trans_depth       2540047 non-null  object
#  25  res_bdy_len       2540047 non-null  object
#  26  Sjit              2540047 non-null  float64
#  27  Djit              2540047 non-null  float64
#  28  Stime             2540047 non-null  object
#  29  Ltime             2540047 non-null  object
#  30  Sintpkt           2540047 non-null  float64
#  31  Dintpkt           2540047 non-null  float64
#  32  tcprtt            2540047 non-null  float64
#  33  synack            2540047 non-null  float64
#  34  ackdat            2540047 non-null  float64
#  35  is_sm_ips_ports   2540047 non-null  object
#  36  ct_state_ttl      2540047 non-null  object
#  37  ct_flw_http_mthd  1191902 non-null  float64
#  38  is_ftp_login      1110168 non-null  float64
#  39  ct_ftp_cmd        2540047 non-null  object
#  40  ct_srv_src        2540047 non-null  object
#  41  ct_srv_dst        2540047 non-null  object
#  42  ct_dst_ltm        2540047 non-null  object
#  43  ct_src_ltm        2540047 non-null  object
#  44  ct_src_dport_ltm  2540047 non-null  object
#  45  ct_dst_sport_ltm  2540047 non-null  object
#  46  ct_dst_src_ltm    2540047 non-null  object
#  47  attack_cat        321283 non-null   object
#  48  Label             2540047 non-null  object
# dtypes: float64(12), object(37)
# memory usage: 949.6+ MB

# %%
# df.head(20)
# Out:
#              srcip  sport           dstip dsport proto state       dur sbytes  \
# 0       59.166.0.1  18247   149.171.126.4   7662   tcp   FIN  0.119596   4550
# 1       59.166.0.3  54771   149.171.126.2  27709   tcp   FIN  0.650574   8928
# 2       59.166.0.8  13289   149.171.126.9   5190   tcp   FIN  0.007980   2158
# 3   149.171.126.18   1043    175.45.176.3     53   udp   INT  0.000005    264
# 4   149.171.126.18   1043    175.45.176.3     53   udp   INT  0.000005    264
# 5       59.166.0.3  10275   149.171.126.0     25   tcp   FIN  0.486578  37462
# 6     175.45.176.0  59932  149.171.126.12    179   tcp   FIN  0.628085    534
# 7       59.166.0.1  21522   149.171.126.0  19847   tcp   FIN  0.137141   4550
# 8       59.166.0.7  30665   149.171.126.7  57704   tcp   FIN  0.079338    320
# 9   149.171.126.18   1043    175.45.176.3     53   udp   INT  0.000005    264
# 10  149.171.126.18   1043    175.45.176.3     53   udp   INT  0.000005    264
# 11  149.171.126.18   1043    175.45.176.3     53   udp   INT  0.000005    264
# 12  149.171.126.18   1043    175.45.176.3     53   udp   INT  0.000005    264
# 13      59.166.0.1   1597   149.171.126.4  63866   tcp   FIN  0.066273   3062
# 14      59.166.0.1  58849   149.171.126.2  65058   tcp   FIN  0.074735   2958
# 15      59.166.0.6  59392   149.171.126.5     80   tcp   FIN  0.058939   1048
# 16  149.171.126.18   1043    175.45.176.3     53   udp   INT  0.000005    264
# 17  149.171.126.18   1043    175.45.176.3     53   udp   INT  0.000005    264
# 18  149.171.126.18   1043    175.45.176.3     53   udp   INT  0.000005    264
# 19  149.171.126.18   1043    175.45.176.3     53   udp   INT  0.000005    264
#
#    dbytes sttl dttl sloss dloss   service         Sload         Dload Spkts  \
# 0   68342   31   29     7    33         -  3.004783e+05  4.514398e+06    78
# 1     320   31   29     4     1  ftp-data  1.019530e+05  3.283254e+03    14
# 2    2464   31   29     6     6         -  2.074185e+06  2.367920e+06    24
# 3       0   60    0     0     0       dns  2.112000e+08  0.000000e+00     2
# 4       0   60    0     0     0       dns  2.112000e+08  0.000000e+00     2
# 5    3380   31   29    18     8      smtp  6.040882e+05  5.425646e+04    52
# 6     354  254  252     2     1         -  6.126559e+03  3.948510e+03    10
# 7   68342   31   29     7    33         -  2.620369e+05  3.936853e+06    78
# 8    1896   31   29     1     2  ftp-data  2.692279e+04  1.672843e+05     6
# 9       0   60    0     0     0       dns  2.112000e+08  0.000000e+00     2
# 10      0   60    0     0     0       dns  2.112000e+08  0.000000e+00     2
# 11      0   60    0     0     0       dns  2.112000e+08  0.000000e+00     2
# 12      0   60    0     0     0       dns  2.112000e+08  0.000000e+00     2
# 13  33060   31   29     7    18         -  3.622592e+05  3.910974e+06    50
# 14  33060   31   29     7    18         -  3.101091e+05  3.468148e+06    48
# 15    824   31   29     2     2      http  1.244677e+05  1.007143e+05     8
# 16      0   60    0     0     0       dns  2.112000e+08  0.000000e+00     2
# 17      0   60    0     0     0       dns  2.112000e+08  0.000000e+00     2
# 18      0   60    0     0     0       dns  2.112000e+08  0.000000e+00     2
# 19      0   60    0     0     0       dns  2.112000e+08  0.000000e+00     2
#
#    Dpkts swin dwin       stcpb       dtcpb smeansz dmeansz trans_depth  \
# 0     80  255  255  1818376620  1818657356      58     854           0
# 1      6  255  255  4075447467  3777413974     638      53           0
# 2     24  255  255  1638377249  1638673555      90     103           0
# 3      0    0    0           0           0     132       0           0
# 4      0    0    0           0           0     132       0           0
# 5     42  255  255  1518379503  3670369209     720      80           0
# 6      8  255  255  2656904324  2464095352      53      44           0
# 7     80  255  255  4087957051  4088184097      58     854           0
# 8      8  255  255  3243766425  1613804297      53     237           0
# 9      0    0    0           0           0     132       0           0
# 10     0    0    0           0           0     132       0           0
# 11     0    0    0           0           0     132       0           0
# 12     0    0    0           0           0     132       0           0
# 13    50  255  255  3963766791  1890480624      61     661           0
# 14    50  255  255  1938379719  2020983832      62     661           0
# 15    10  255  255  3843771648  3850731231     131      82           1
# 16     0    0    0           0           0     132       0           0
# 17     0    0    0           0           0     132       0           0
# 18     0    0    0           0           0     132       0           0
# 19     0    0    0           0           0     132       0           0
#
#    res_bdy_len         Sjit        Djit       Stime       Ltime    Sintpkt  \
# 0            0    87.137592   85.643619  1424231129  1424231129   1.549156
# 1            0  4045.664812  162.187656  1424231129  1424231129  50.044153
# 2            0    23.013883    0.487342  1424231129  1424231129   0.347545
# 3            0     0.000000    0.000000  1424231129  1424231129   0.005000
# 4            0     0.000000    0.000000  1424231129  1424231129   0.005000
# 5            0   768.061343   24.935787  1424231128  1424231129   9.533961
# 6            0  4626.171078  134.850297  1424231129  1424231129  69.693889
# 7            0    99.378940   97.705561  1424231129  1424231129   1.776584
# 8            0  1106.729846   27.250656  1424231129  1424231129  15.804400
# 9            0     0.000000    0.000000  1424231129  1424231129   0.005000
# 10           0     0.000000    0.000000  1424231129  1424231129   0.005000
# 11           0     0.000000    0.000000  1424231129  1424231129   0.005000
# 12           0     0.000000    0.000000  1424231129  1424231129   0.005000
# 13           0    78.068841    2.050742  1424231129  1424231129   1.346204
# 14           0    97.483565   92.858987  1424231129  1424231129   1.583426
# 15          83   484.457095   11.726373  1424231129  1424231129   8.251143
# 16           0     0.000000    0.000000  1424231129  1424231129   0.005000
# 17           0     0.000000    0.000000  1424231129  1424231129   0.005000
# 18           0     0.000000    0.000000  1424231129  1424231129   0.005000
# 19           0     0.000000    0.000000  1424231129  1424231129   0.005000
#
#        Dintpkt    tcprtt    synack    ackdat is_sm_ips_ports ct_state_ttl  \
# 0     1.507190  0.000644  0.000521  0.000123               0            0
# 1   129.990797  0.000616  0.000495  0.000121               0            0
# 2     0.322913  0.000668  0.000544  0.000124               0            0
# 3     0.000000  0.000000  0.000000  0.000000               0            0
# 4     0.000000  0.000000  0.000000  0.000000               0            0
# 5    11.645000  0.016012  0.009132  0.006880               0            0
# 6    79.491289  0.112146  0.071639  0.040507               0            1
# 7     1.729747  0.000608  0.000487  0.000121               0            0
# 8    11.253000  0.000743  0.000563  0.000180               0            0
# 9     0.000000  0.000000  0.000000  0.000000               0            0
# 10    0.000000  0.000000  0.000000  0.000000               0            0
# 11    0.000000  0.000000  0.000000  0.000000               0            0
# 12    0.000000  0.000000  0.000000  0.000000               0            0
# 13    1.341714  0.000648  0.000526  0.000122               0            0
# 14    1.514980  0.000609  0.000496  0.000113               0            0
# 15    6.494111  0.000612  0.000487  0.000125               0            0
# 16    0.000000  0.000000  0.000000  0.000000               0            0
# 17    0.000000  0.000000  0.000000  0.000000               0            0
# 18    0.000000  0.000000  0.000000  0.000000               0            0
# 19    0.000000  0.000000  0.000000  0.000000               0            0
#
#     ct_flw_http_mthd  is_ftp_login ct_ftp_cmd ct_srv_src ct_srv_dst  \
# 0                NaN           NaN                     6          2
# 1                NaN           NaN                     3          5
# 2                NaN           NaN                     3          5
# 3                NaN           NaN                    19         19
# 4                NaN           NaN                    19         19
# 5                NaN           NaN                     3          2
# 6                NaN           NaN                     6          4
# 7                NaN           NaN                     6          3
# 8                NaN           NaN                     1          1
# 9                NaN           NaN                    19         19
# 10               NaN           NaN                    19         19
# 11               NaN           NaN                    19         19
# 12               NaN           NaN                    19         19
# 13               NaN           NaN                     6          2
# 14               NaN           NaN                     6          3
# 15               1.0           NaN                     3          1
# 16               NaN           NaN                    19         19
# 17               NaN           NaN                    19         19
# 18               NaN           NaN                    19         19
# 19               NaN           NaN                    19         19
#
#    ct_dst_ltm ct_src_ltm ct_src_dport_ltm ct_dst_sport_ltm ct_dst_src_ltm  \
# 0           2          5                1                1              2
# 1           2          4                1                1              4
# 2           1          1                1                1              3
# 3          19         19               19               19             19
# 4          19         19               19               19             19
# 5           3          4                2                1              2
# 6           1          1                1                1              4
# 7           3          5                1                1              2
# 8           1          1                1                1              3
# 9          19         19               19               19             19
# 10         19         19               19               19             19
# 11         19         19               19               19             19
# 12         19         19               19               19             19
# 13          2          5                1                1              2
# 14          2          5                1                1              1
# 15          3          3                2                1              1
# 16         19         19               19               19             19
# 17         19         19               19               19             19
# 18         19         19               19               19             19
# 19         19         19               19               19             19
#
#    attack_cat Label
# 0         NaN     0
# 1         NaN     0
# 2         NaN     0
# 3         NaN     0
# 4         NaN     0
# 5         NaN     0
# 6         NaN     0
# 7         NaN     0
# 8         NaN     0
# 9         NaN     0
# 10        NaN     0
# 11        NaN     0
# 12        NaN     0
# 13        NaN     0
# 14        NaN     0
# 15        NaN     0
# 16        NaN     0
# 17        NaN     0
# 18        NaN     0
# 19        NaN     0

# %%
df['attack_cat'].value_counts()
# Out:
# Generic             215481
# Exploits             44525
#  Fuzzers             19195
# DoS                  16353
#  Reconnaissance      12228
#  Fuzzers              5051
# Analysis              2677
# Backdoor              1795
# Reconnaissance        1759
#  Shellcode            1288
# Backdoors              534
# Shellcode              223
# Worms                  174
# Name: attack_cat, dtype: int64

# %%
# Useless - more for snort rules

df.drop(['srcip', 'dstip', 'Stime', 'Ltime'], axis=1, inplace=True)

# %%
# More than 50% empty - delete columns

df.drop(['ct_flw_http_mthd', 'is_ftp_login', 'ct_ftp_cmd'], axis=1, inplace=True)

# %%
# convert class into numerics

cols_to_numeric = df.select_dtypes(include=['object']).columns.drop(['proto', 'service', 'state', 'attack_cat'])
df[cols_to_numeric] = df[cols_to_numeric].apply(pd.to_numeric, errors='coerce')

# %%
df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2540047 entries, 0 to 2540046
# Data columns (total 42 columns):
#  #   Column            Non-Null Count    Dtype
# ---  ------            --------------    -----
#  0   sport             2540039 non-null  float64
#  1   dsport            2539743 non-null  float64
#  2   proto             2540047 non-null  object
#  3   state             2540047 non-null  object
#  4   dur               2540047 non-null  float64
#  5   sbytes            2540047 non-null  int64
#  6   dbytes            2540047 non-null  int64
#  7   sttl              2540047 non-null  int64
#  8   dttl              2540047 non-null  int64
#  9   sloss             2540047 non-null  int64
#  10  dloss             2540047 non-null  int64
#  11  service           2540047 non-null  object
#  12  Sload             2540047 non-null  float64
#  13  Dload             2540047 non-null  float64
#  14  Spkts             2540047 non-null  int64
#  15  Dpkts             2540047 non-null  int64
#  16  swin              2540047 non-null  int64
#  17  dwin              2540047 non-null  int64
#  18  stcpb             2540047 non-null  int64
#  19  dtcpb             2540047 non-null  int64
#  20  smeansz           2540047 non-null  int64
#  21  dmeansz           2540047 non-null  int64
#  22  trans_depth       2540047 non-null  int64
#  23  res_bdy_len       2540047 non-null  int64
#  24  Sjit              2540047 non-null  float64
#  25  Djit              2540047 non-null  float64
#  26  Sintpkt           2540047 non-null  float64
#  27  Dintpkt           2540047 non-null  float64
#  28  tcprtt            2540047 non-null  float64
#  29  synack            2540047 non-null  float64
#  30  ackdat            2540047 non-null  float64
#  31  is_sm_ips_ports   2540047 non-null  int64
#  32  ct_state_ttl      2540047 non-null  int64
#  33  ct_srv_src        2540047 non-null  int64
#  34  ct_srv_dst        2540047 non-null  int64
#  35  ct_dst_ltm        2540047 non-null  int64
#  36  ct_src_ltm        2540047 non-null  int64
#  37  ct_src_dport_ltm  2540047 non-null  int64
#  38  ct_dst_sport_ltm  2540047 non-null  int64
#  39  ct_dst_src_ltm    2540047 non-null  int64
#  40  attack_cat        321283 non-null   object
#  41  Label             2540047 non-null  int64
# dtypes: float64(12), int64(26), object(4)
# memory usage: 813.9+ MB

# %%
df['attack_cat'].value_counts()
# Out:
# Generic             215481
# Exploits             44525
#  Fuzzers             19195
# DoS                  16353
#  Reconnaissance      12228
#  Fuzzers              5051
# Analysis              2677
# Backdoor              1795
# Reconnaissance        1759
#  Shellcode            1288
# Backdoors              534
# Shellcode              223
# Worms                  174
# Name: attack_cat, dtype: int64

# %%
# Function to group attacks into a larger subset

def attack_type_to_int(row):
    label = str(row['attack_cat']).strip()
    if label == 'Generic':
        return 1
    elif label == 'Exploits': 
        return 2
    elif label == 'Fuzzers':
        return 3
    elif label == 'DoS':
        return 4
    elif label == 'Reconnaissance': 
        return 5
    elif label == 'Analysis':
        return 6
    elif label == 'Backdoor' or label == 'Backdoors': 
        return 7
    elif label == 'Shellcode':
        return 8
    elif label == 'Worms':
        return 9
    else:
        return 0

# %%
df['attack_type'] = df.apply(lambda row: attack_type_to_int(row), axis=1)
df = df.drop(['attack_cat', 'Label'], axis=1)
df = df.replace([np.inf], np.nan)
df.isnull().sum()
# Out:
# sport                 8
# dsport              304
# proto                 0
# state                 0
# dur                   0
# sbytes                0
# dbytes                0
# sttl                  0
# dttl                  0
# sloss                 0
# dloss                 0
# service               0
# Sload                 0
# Dload                 0
# Spkts                 0
# Dpkts                 0
# swin                  0
# dwin                  0
# stcpb                 0
# dtcpb                 0
# smeansz               0
# dmeansz               0
# trans_depth           0
# res_bdy_len           0
# Sjit                  0
# Djit                  0
# Sintpkt               0
# Dintpkt               0
# tcprtt                0
# synack                0
# ackdat                0
# is_sm_ips_ports       0
# ct_state_ttl          0
# ct_srv_src            0
# ct_srv_dst            0
# ct_dst_ltm            0
# ct_src_ltm            0
# ct_src_dport_ltm      0
# ct_dst_sport_ltm      0
# ct_dst_src_ltm        0
# attack_type           0
# dtype: int64

# %%
# Drop all null columns

df = df.dropna()

# %%
df['attack_type'].value_counts()
# Out:
# 0    2218456
# 1     215481
# 2      44525
# 3      24246
# 4      16353
# 5      13987
# 6       2677
# 7       2329
# 8       1511
# 9        174
# Name: attack_type, dtype: int64

# %%
# Downsample benign class

df_0 = df[df.attack_type==0]

df_0 = resample(df_0, replace=False, n_samples=500000, random_state=25) 
df_rest = df[df.attack_type>0]

df = pd.concat([df_0, df_rest])

# %%
df.info(null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 821283 entries, 2089206 to 2540046
# Data columns (total 41 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   sport             821283 non-null  float64
#  1   dsport            821283 non-null  float64
#  2   proto             821283 non-null  object
#  3   state             821283 non-null  object
#  4   dur               821283 non-null  float64
#  5   sbytes            821283 non-null  int64
#  6   dbytes            821283 non-null  int64
#  7   sttl              821283 non-null  int64
#  8   dttl              821283 non-null  int64
#  9   sloss             821283 non-null  int64
#  10  dloss             821283 non-null  int64
#  11  service           821283 non-null  object
#  12  Sload             821283 non-null  float64
#  13  Dload             821283 non-null  float64
#  14  Spkts             821283 non-null  int64
#  15  Dpkts             821283 non-null  int64
#  16  swin              821283 non-null  int64
#  17  dwin              821283 non-null  int64
#  18  stcpb             821283 non-null  int64
#  19  dtcpb             821283 non-null  int64
#  20  smeansz           821283 non-null  int64
#  21  dmeansz           821283 non-null  int64
#  22  trans_depth       821283 non-null  int64
#  23  res_bdy_len       821283 non-null  int64
#  24  Sjit              821283 non-null  float64
#  25  Djit              821283 non-null  float64
#  26  Sintpkt           821283 non-null  float64
#  27  Dintpkt           821283 non-null  float64
#  28  tcprtt            821283 non-null  float64
#  29  synack            821283 non-null  float64
#  30  ackdat            821283 non-null  float64
#  31  is_sm_ips_ports   821283 non-null  int64
#  32  ct_state_ttl      821283 non-null  int64
#  33  ct_srv_src        821283 non-null  int64
#  34  ct_srv_dst        821283 non-null  int64
#  35  ct_dst_ltm        821283 non-null  int64
#  36  ct_src_ltm        821283 non-null  int64
#  37  ct_src_dport_ltm  821283 non-null  int64
#  38  ct_dst_sport_ltm  821283 non-null  int64
#  39  ct_dst_src_ltm    821283 non-null  int64
#  40  attack_type       821283 non-null  int64
# dtypes: float64(12), int64(26), object(3)
# memory usage: 263.2+ MB

# %%
df.describe()
# Out:
#                sport         dsport            dur        sbytes  \
# count  821283.000000  821283.000000  821283.000000  8.212830e+05
# mean    28091.754789    8041.088141       0.688129  4.798523e+03
# std     21617.746420   16412.577531      14.234278  9.794037e+04
# min         0.000000       0.000000       0.000000  0.000000e+00
# 25%      3030.000000      53.000000       0.000009  1.140000e+02
# 50%     29263.000000      53.000000       0.003015  4.240000e+02
# 75%     47439.000000    5190.000000       0.132792  2.599000e+03
# max     65535.000000   65535.000000    8760.776367  1.435577e+07
#
#              dbytes           sttl           dttl          sloss  \
# count  8.212830e+05  821283.000000  821283.000000  821283.000000
# mean   2.682287e+04     116.545749      35.404670       4.391761
# std    1.495555e+05     106.204020      64.757246      37.447692
# min    0.000000e+00       0.000000       0.000000       0.000000
# 25%    0.000000e+00      31.000000       0.000000       0.000000
# 50%    2.680000e+02      31.000000      29.000000       0.000000
# 75%    6.806000e+03     254.000000      29.000000       7.000000
# max    1.465753e+07     255.000000     254.000000    5319.000000
#
#                dloss         Sload         Dload          Spkts  \
# count  821283.000000  8.212830e+05  8.212830e+05  821283.000000
# mean       12.039974  5.507902e+07  1.706288e+06      25.977870
# std        53.249950  1.334634e+08  3.696850e+06      91.997898
# min         0.000000  0.000000e+00  0.000000e+00       0.000000
# 25%         0.000000  2.444531e+05  0.000000e+00       2.000000
# 50%         0.000000  1.090184e+06  4.692534e+04       4.000000
# 75%         7.000000  5.700000e+07  7.170191e+05      28.000000
# max      5507.000000  5.988000e+09  1.287619e+08   10646.000000
#
#                Dpkts           swin           dwin         stcpb  \
# count  821283.000000  821283.000000  821283.000000  8.212830e+05
# mean       31.577303     118.677724     118.443303  9.974075e+08
# std       113.768574     127.194150     127.177351  1.364729e+09
# min         0.000000       0.000000       0.000000  0.000000e+00
# 25%         0.000000       0.000000       0.000000  0.000000e+00
# 50%         4.000000       0.000000       0.000000  0.000000e+00
# 75%        24.000000     255.000000     255.000000  1.978163e+09
# max     11018.000000     255.000000     255.000000  4.294959e+09
#
#               dtcpb        smeansz        dmeansz    trans_depth  \
# count  8.212830e+05  821283.000000  821283.000000  821283.000000
# mean   9.994204e+08     116.499358     203.651638       0.075177
# std    1.365964e+09     154.585285     312.787461       0.449384
# min    0.000000e+00       0.000000       0.000000       0.000000
# 25%    0.000000e+00      57.000000       0.000000       0.000000
# 50%    0.000000e+00      65.000000      79.000000       0.000000
# 75%    1.988718e+09     117.000000     215.000000       0.000000
# max    4.294954e+09    1504.000000    1480.000000     172.000000
#
#         res_bdy_len          Sjit           Djit        Sintpkt  \
# count  8.212830e+05  8.212830e+05  821283.000000  821283.000000
# mean   3.213996e+03  1.873289e+03     582.296468     151.397155
# std    4.569276e+04  2.244921e+04    3239.124021    2365.102429
# min    0.000000e+00  0.000000e+00       0.000000       0.000000
# 25%    0.000000e+00  0.000000e+00       0.000000       0.008000
# 50%    0.000000e+00  0.000000e+00       0.286857       0.271286
# 75%    0.000000e+00  1.794311e+02      47.846251       4.831822
# max    6.558056e+06  1.483831e+06  781221.118300   84371.496000
#
#              Dintpkt         tcprtt         synack         ackdat  \
# count  821283.000000  821283.000000  821283.000000  821283.000000
# mean       64.554809       0.011453       0.005815       0.005638
# std      1186.924460       0.050187       0.027267       0.025736
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.212667       0.000000       0.000000       0.000000
# 75%         2.855650       0.000691       0.000546       0.000138
# max     57739.240000       5.059004       3.266399       3.518718
#
#        is_sm_ips_ports   ct_state_ttl     ct_srv_src     ct_srv_dst  \
# count    821283.000000  821283.000000  821283.000000  821283.000000
# mean          0.001179       0.736543      12.519441      12.329506
# std           0.034311       0.955873      13.201063      13.247163
# min           0.000000       0.000000       1.000000       1.000000
# 25%           0.000000       0.000000       3.000000       2.000000
# 50%           0.000000       0.000000       6.000000       6.000000
# 75%           0.000000       2.000000      20.000000      20.000000
# max           1.000000       6.000000      67.000000      67.000000
#
#           ct_dst_ltm    ct_src_ltm  ct_src_dport_ltm  ct_dst_sport_ltm  \
# count  821283.000000  821283.00000     821283.000000     821283.000000
# mean        8.652883       9.14804          7.326918          5.655733
# std        10.061286      10.06940         10.505754          7.531575
# min         1.000000       1.00000          1.000000          1.000000
# 25%         2.000000       2.00000          1.000000          1.000000
# 50%         4.000000       5.00000          1.000000          1.000000
# 75%        13.000000      14.00000         12.000000          9.000000
# max        67.000000      67.00000         67.000000         60.000000
#
#        ct_dst_src_ltm    attack_type
# count   821283.000000  821283.000000
# mean        10.795756       0.680198
# std         13.933558       1.190721
# min          1.000000       0.000000
# 25%          1.000000       0.000000
# 50%          3.000000       0.000000
# 75%         19.000000       1.000000
# max         67.000000       9.000000

# %%
#  Categorize ports:

df['is_well_known_port_src'] = df.apply(lambda row: 1 if row['sport'] < 1024 else 0, axis=1)
print('...')
df['is_registered_port_src'] = df.apply(lambda row: 1 if row['sport'] >= 1024 and row['sport'] < 49152 else 0, axis=1)
print('processing dest port')

df['is_well_known_port_dst'] = df.apply(lambda row: 1 if row['dsport'] < 1024 else 0, axis=1)
print('...')
df['is_registered_port_dst'] = df.apply(lambda row: 1 if row['dsport'] >= 1024 and row['dsport'] < 49152 else 0, axis=1)

df = df.drop(columns = ['sport', 'dsport'], axis=1)
# Out:
# ...
# processing dest port
# ...

# %%
# Apply scaling to all relevant columns in train and then transform test as well

scaler = StandardScaler()

cols_to_scale = df.columns.drop(['proto', 'service', 'state', 'is_sm_ips_ports', 'attack_type'])

df[cols_to_scale] = scaler.fit_transform(df[cols_to_scale])

# %%
print(df['proto'].value_counts())
print(df['service'].value_counts())
print(df['state'].value_counts())
# Out:
# udp            396325
# tcp            382236
# unas            16202
# ospf             4331
# arp              2252
# sctp             1525
# any               411
# gre               324
# rsvp              274
# ipv6              272
# mobile            262
# pim               262
# sun-nd            262
# swipe             262
# sep               260
# ib                137
# netblt            137
# iatp              137
# ipv6-no           137
# mhrp              137
# dgp               137
# i-nlsp            137
# ipcv              137
# larp              137
# leaf-1            137
# pgm               137
# ipnip             137
# pipe              137
# crudp             137
# sat-expak         137
# trunk-2           137
# il                137
# irtp              137
# egp               137
# idpr              137
# wsn               137
# secure-vmtp       137
# trunk-1           137
# ipv6-route        137
# aris              137
# 3pc               137
# sprite-rpc        137
# srp               137
# wb-expak          137
# ipip              137
# ip                137
# etherip           137
# ax.25             137
# eigrp             137
# ipcomp            137
# fc                137
# a/n               137
# emcon             137
# st2               137
# idpr-cmtp         137
# pri-enc           137
# rdp               137
# zero              137
# nvp               137
# nsfnet-igp        137
# merit-inp         137
# vmtp              137
# bna               137
# sps               137
# isis              137
# pup               137
# pvp               137
# ipv6-opts         137
# mtp               137
# bbn-rcc           137
# ddx               137
# pnni              137
# fire              137
# sdrp              137
# ddp               137
# hmp               137
# sat-mon           137
# iso-tp4           137
# igp               137
# mfe-nsp           137
# micp              137
# xns-idp           137
# ggp               137
# iplt              137
# smp               137
# iso-ip            137
# kryptolan         137
# sm                137
# wb-mon            137
# skip              137
# scps              137
# qnx               137
# xnet              137
# vines             137
# argus             137
# ipv6-frag         137
# vrrp              137
# aes-sp3-d         137
# br-sat-mon        137
# chaos             137
# sccopmce          137
# ippc              137
# idrp              137
# ifmp              137
# tlsp              137
# cbt               137
# ttp               137
# uti               137
# ptp               137
# crtp              137
# encap             137
# compaq-peer       137
# ipx-n-ip          137
# gmtp              137
# rvd               137
# l2tp              137
# cpnx              137
# prm               137
# tcf               137
# tp++              137
# cphb              137
# snp               137
# narp              137
# xtp               137
# mux               137
# stp               137
# cftp              137
# leaf-2            137
# dcn               137
# visa              137
# icmp               50
# igmp               13
# rtp                 4
# udt                 1
# Name: proto, dtype: int64
# -           342535
# dns         339383
# http         61143
# ftp-data     29680
# smtp         22362
# ftp          13426
# ssh          10737
# pop3          1529
# dhcp           172
# ssl            142
# snmp           112
# radius          32
# irc             30
# Name: service, dtype: int64
# FIN    378307
# INT    312515
# CON    127214
# REQ      3014
# RST       132
# CLO        42
# ECO        19
# URH        13
# ACC         9
# PAR         7
# TXD         3
# TST         3
# URN         2
# no          1
# MAS         1
# ECR         1
# Name: state, dtype: int64

# %%
# Categorize protocol, service types, and state:

def value_checker(row, col_name, value):
    if row[col_name] == value:
        return 1
    else:
        return 0

# %%
# Pseudo dummy variables for protocols, services and states

protocols = ['tcp', 'udp', 'unas', 'arp', 'ospf', 'sctp']
services = ['dns', 'http', 'smtp', 'ftp-data', 'ftp', 'ssh', 'pop3']
states = ['INT', 'FIN', 'CON', 'REQ']

for protocol in protocols:
    col_name = 'protocol_' + protocol
    df[col_name] = df.apply(lambda row: value_checker(row, 'proto', protocol), axis=1)
    print('added', col_name)

for service in services:
    col_name = 'service_' + service
    df[col_name] = df.apply(lambda row: value_checker(row, 'service', service), axis=1)
    print('added', col_name)

for state in states:
    col_name = 'state_' + state
    df[col_name] = df.apply(lambda row: value_checker(row, 'state', state), axis=1)
    print('added', col_name)


df.drop(['proto', 'service', 'state'],axis=1, inplace=True)
# Out:
# added protocol_tcp
# added protocol_udp
# added protocol_unas
# added protocol_arp
# added protocol_ospf
# added protocol_sctp
# added service_dns
# added service_http
# added service_smtp
# added service_ftp-data
# added service_ftp
# added service_ssh
# added service_pop3
# added state_INT
# added state_FIN
# added state_CON
# added state_REQ

# %%
# df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 821283 entries, 2089206 to 2540046
# Data columns (total 57 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   dur                     821283 non-null  float64
#  1   sbytes                  821283 non-null  float64
#  2   dbytes                  821283 non-null  float64
#  3   sttl                    821283 non-null  float64
#  4   dttl                    821283 non-null  float64
#  5   sloss                   821283 non-null  float64
#  6   dloss                   821283 non-null  float64
#  7   Sload                   821283 non-null  float64
#  8   Dload                   821283 non-null  float64
#  9   Spkts                   821283 non-null  float64
#  10  Dpkts                   821283 non-null  float64
#  11  swin                    821283 non-null  float64
#  12  dwin                    821283 non-null  float64
#  13  stcpb                   821283 non-null  float64
#  14  dtcpb                   821283 non-null  float64
#  15  smeansz                 821283 non-null  float64
#  16  dmeansz                 821283 non-null  float64
#  17  trans_depth             821283 non-null  float64
#  18  res_bdy_len             821283 non-null  float64
#  19  Sjit                    821283 non-null  float64
#  20  Djit                    821283 non-null  float64
#  21  Sintpkt                 821283 non-null  float64
#  22  Dintpkt                 821283 non-null  float64
#  23  tcprtt                  821283 non-null  float64
#  24  synack                  821283 non-null  float64
#  25  ackdat                  821283 non-null  float64
#  26  is_sm_ips_ports         821283 non-null  int64
#  27  ct_state_ttl            821283 non-null  float64
#  28  ct_srv_src              821283 non-null  float64
#  29  ct_srv_dst              821283 non-null  float64
#  30  ct_dst_ltm              821283 non-null  float64
#  31  ct_src_ltm              821283 non-null  float64
#  32  ct_src_dport_ltm        821283 non-null  float64
#  33  ct_dst_sport_ltm        821283 non-null  float64
#  34  ct_dst_src_ltm          821283 non-null  float64
#  35  attack_type             821283 non-null  int64
#  36  is_well_known_port_src  821283 non-null  float64
#  37  is_registered_port_src  821283 non-null  float64
#  38  is_well_known_port_dst  821283 non-null  float64
#  39  is_registered_port_dst  821283 non-null  float64
#  40  protocol_tcp            821283 non-null  int64
#  41  protocol_udp            821283 non-null  int64
#  42  protocol_unas           821283 non-null  int64
#  43  protocol_arp            821283 non-null  int64
#  44  protocol_ospf           821283 non-null  int64
#  45  protocol_sctp           821283 non-null  int64
#  46  service_dns             821283 non-null  int64
#  47  service_http            821283 non-null  int64
#  48  service_smtp            821283 non-null  int64
#  49  service_ftp-data        821283 non-null  int64
#  50  service_ftp             821283 non-null  int64
#  51  service_ssh             821283 non-null  int64
#  52  service_pop3            821283 non-null  int64
#  53  state_INT               821283 non-null  int64
#  54  state_FIN               821283 non-null  int64
#  55  state_CON               821283 non-null  int64
#  56  state_REQ               821283 non-null  int64
# dtypes: float64(38), int64(19)
# memory usage: 363.4 MB

# %%
# # Determine columns in extended matrix with correlation >.95

# df_corr = df.drop(['attack_type'],axis=1)

# corr_matrix = df_corr.corr().abs()
# upper = corr_matrix.where(np.triu(np.ones(corr_matrix.shape), k=1).astype(np.bool))
# to_drop_95 = [column for column in upper.columns if any(upper[column] > 0.95)]

# to_drop_95
# Out:
# ['sloss',
#  'dloss',
#  'Dpkts',
#  'dwin',
#  'ct_srv_dst',
#  'ct_src_ltm',
#  'ct_src_dport_ltm',
#  'ct_dst_src_ltm',
#  'protocol_tcp',
#  'state_FIN']

# %%
# Split dfs into features and labels

# def attack_type_to_int(row):
#     if row['attack_type'] == 0:
#         return 0
#     else:
# #         return 1

# df['is_attack'] = df.apply(lambda row: 1 if row['attack_type'] > 0 else 0, axis=1)
# df['is_attack'].value_counts()
# Out:
# 0    500000
# 1    321283
# Name: is_attack, dtype: int64

# %%
df = df.sample(frac=1).reset_index(drop=True)

y = df['is_attack']
X = df.drop(['is_attack'], axis=1)

y.value_counts()
# Out:
# 0    500000
# 1    321283
# Name: is_attack, dtype: int64

# %%
# Split dfs into features and labels

# df = df.sample(frac=1).reset_index(drop=True)

# df = df.drop(['is_attack'], axis=1)

y = df['attack_type']
X = df.drop(['attack_type'], axis=1)

X_train, X_test, y_train, y_test = train_test_split(
        X, y,
        train_size=0.7,
        test_size=0.3,
        random_state=65878,
        stratify=y
    )

print(y_train.value_counts())
# print(X_train['attack_type'].value_counts())
print(y_test.value_counts())
# print(X_test['attack_type'].value_counts())

# Create train and test with correlated features removed
# X_train_95 = X_train.drop(to_drop_95, axis=1)
# X_test_95 = X_test.drop(to_drop_95, axis=1)
# Out:
# 0    350000
# 1    150837
# 2     31167
# 3     16972
# 4     11447
# 5      9791
# 6      1874
# 7      1630
# 8      1058
# 9       122
# Name: attack_type, dtype: int64
# 0    150000
# 1     64644
# 2     13358
# 3      7274
# 4      4906
# 5      4196
# 6       803
# 7       699
# 8       453
# 9        52
# Name: attack_type, dtype: int64

# %%
# X_train = X_train.drop(['attack_type'], axis=1)
# X_test = X_test.drop(['attack_type'], axis=1)

# %%
# Combine minority classes for better class balance

y_train = y_train.apply(lambda x: 1 if x > 0 else 0)
y_test = y_test.apply(lambda x: 1 if x > 0 else 0)

print(y_train.value_counts())
print(y_test.value_counts())
# Out:
# 0    350000
# 1    224898
# Name: attack_type, dtype: int64
# 0    150000
# 1     96385
# Name: attack_type, dtype: int64

# %%
def fit_and_score_ensemble_classifier(model, X_train, y_train, X_test, y_test):
    model.fit(X_train, y_train)
    y_pred = model.predict(X_test)
    predictions = [round(value) for value in y_pred]

    print('Accuracy:', accuracy_score(y_test, y_pred), '\n')
    print(precision_recall_fscore_support(y_test, y_pred), '\n')
    print('F1_score:', f1_score(y_test, y_pred), '\n')
    print(classification_report(y_test, y_pred), '\n')
    print(confusion_matrix(y_test, y_pred), '\n')
    print(confusion_matrix(y_test, y_pred, normalize='true'), '\n')

    
# def plot_feature_importances(model, labels, color):
#     values = model.feature_importances_
#     index = np.arange(len(labels))
#     fig = plt.figure(figsize=(16, 10))
#     plt.bar(index, values, color=color)
#     plt.xlabel('Feature', fontsize=10)
#     plt.ylabel('Importance', fontsize=10)
#     plt.xticks(index, labels, fontsize=10, rotation=90)
#     plt.show()

# def export_model(model, filename):
#     # Dump to a retrievable file: model = load('filename.joblib') 
#     dump(model, filename + '.joblib') 
#     # save to Onnx file type
#     initial_type = [('float_input', FloatTensorType([None, 70]))]
#     onx = convert_sklearn(rf_model, initial_types=initial_type)
#     with open(filename + '.onnx', 'wb') as f:
#         f.write(onx.SerializeToString())

# %%
# Random Forest on all columns

rf_model = RandomForestClassifier(n_estimators=100, 
                            bootstrap = True,
                            max_features = 'sqrt',
                            verbose=True,
                            random_state=25)

fit_and_score_ensemble_classifier(rf_model, X_train, y_train, X_test, y_test)
plot_feature_importances(rf_model, X_train.columns, 'green')
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:  1.3min finished
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 100 out of 100 | elapsed:    1.6s finished
# Accuracy: 0.992503602086166
#
# (array([0.99806359, 0.9840358 ]), array([0.98960667, 0.99701198]), array([0.99381714, 0.99048139]), array([150000,  96385]))
#
# F1_score: 0.9904813931076423
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    150000
#            1       0.98      1.00      0.99     96385
#
#     accuracy                           0.99    246385
#    macro avg       0.99      0.99      0.99    246385
# weighted avg       0.99      0.99      0.99    246385
#
#
# [[148441   1559]
#  [   288  96097]]
#
# [[0.98960667 0.01039333]
#  [0.00298802 0.99701198]]

# %%
# # Random Forest Classifier on reduced_95 

# rf_model_95 = RandomForestClassifier(n_estimators=100, 
#                             bootstrap = True,
#                             max_features = 'sqrt',
#                             verbose=True,
#                             random_state=25)

# fit_and_score_ensemble_classifier(rf_model_95, X_train_95, y_train, X_test_95, y_test)
# plot_feature_importances(rf_model_95, X_train_95.columns, 'green')

# %%
# XGB on all columns

xgb_model = XGBClassifier(verbosity=1, importance_type='gain', random_state=25)

fit_and_score_ensemble_classifier(xgb_model, X_train, y_train, X_test, y_test)
plot_feature_importances(xgb_model, X_train.columns, 'green')
# Out:
# Accuracy: 0.992312843720194
#
# (array([0.99788885, 0.98381993]), array([0.98946667, 0.99674223]), array([0.99365991, 0.99023892]), array([150000,  96385]))
#
# F1_score: 0.990238924735616
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    150000
#            1       0.98      1.00      0.99     96385
#
#     accuracy                           0.99    246385
#    macro avg       0.99      0.99      0.99    246385
# weighted avg       0.99      0.99      0.99    246385
#
#
# [[148420   1580]
#  [   314  96071]]
#
# [[0.98946667 0.01053333]
#  [0.00325777 0.99674223]]

# %%
# # XGB on 95 reduced

# xgb_model_95 = XGBClassifier(verbosity=1, importance_type='gain', random_state=25)

# fit_and_score_ensemble_classifier(xgb_model_95, X_train_95, y_train, X_test_95, y_test)
# plot_feature_importances(xgb_model_95, X_train_95.columns, 'green')

# %%
# LGBM on all columns

lgbm_model = LGBMClassifier(silent=False, random_state=25)

fit_and_score_ensemble_classifier(lgbm_model, X_train, y_train, X_test, y_test)
plot_feature_importances(lgbm_model, X_train.columns, 'green')
# Out:
# Accuracy: 0.9921180266655844
#
# (array([0.99853193, 0.98238858]), array([0.98850667, 0.99773824]), array([0.99349401, 0.99000391]), array([150000,  96385]))
#
# F1_score: 0.990003911960304
#
#               precision    recall  f1-score   support
#
#            0       1.00      0.99      0.99    150000
#            1       0.98      1.00      0.99     96385
#
#     accuracy                           0.99    246385
#    macro avg       0.99      0.99      0.99    246385
# weighted avg       0.99      0.99      0.99    246385
#
#
# [[148276   1724]
#  [   218  96167]]
#
# [[0.98850667 0.01149333]
#  [0.00226176 0.99773824]]

# %%
# # LGBM on 95 reduced

# lgbm_model_95 = LGBMClassifier(silent=False, random_state=1001)

# fit_and_score_ensemble_classifier(lgbm_model_95, X_train_95, y_train, X_test_95, y_test)
# plot_feature_importances(lgbm_model_95, X_train_95.columns, 'green')
